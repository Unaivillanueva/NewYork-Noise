# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
#load data NYNoise
data = pd.DataFrame.from_csv(
    'NYNoise.csv', index_col=None, encoding='utf-8')

data.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    31888179  11/01/2015 02:15:00 PM  11/02/2015 09:00:00 AM    DEP
# 1    31889954  11/01/2015 02:34:00 PM  11/08/2015 10:45:00 AM    DEP
# 2    31891076  11/01/2015 10:05:00 PM  11/02/2015 08:40:00 AM    DEP
# 3    31891599  11/01/2015 07:42:00 AM                     NaN    DEP
# 4    31902078  11/03/2015 09:27:00 PM  11/09/2015 10:00:00 PM    DEP
#
#                               Agency Name Complaint Type  \
# 0  Department of Environmental Protection          Noise
# 1  Department of Environmental Protection          Noise
# 2  Department of Environmental Protection          Noise
# 3  Department of Environmental Protection          Noise
# 4  Department of Environmental Protection          Noise
#
#                                      Descriptor  Location Type  Incident Zip  \
# 0                           Noise: Alarms (NR3)            NaN       11366.0
# 1          Noise: Boat(Engine,Music,Etc) (NR10)            NaN       10282.0
# 2                      Noise, Barking Dog (NR5)            NaN       10023.0
# 3  Noise: Construction Before/After Hours (NM1)            NaN       11232.0
# 4          Noise: Boat(Engine,Music,Etc) (NR10)            NaN       11354.0
#
#         Incident Address                    ...                     \
# 0  159-06 UNION TURNPIKE                    ...
# 1        8 RIVER TERRACE                    ...
# 2   119 WEST   71 STREET                    ...
# 3           904 4 AVENUE                    ...
# 4                    NaN                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.720328 -73.807761  (40.720328269590894, -73.80776061338688)
# 1  40.715904 -74.016478     (40.715903834361, -74.01647820382685)
# 2  40.777070 -73.980055    (40.7770700173837, -73.98005490162336)
# 3  40.655822 -74.002865    (40.6558219386325, -74.00286523067972)
# 4  40.772013 -73.848860  (40.772012875575754, -73.84885976567074)
#
# [5 rows x 53 columns]

# %%
#number of rows
print "Number of rows:", len(data)
# Out:
# Number of rows: 82294

# %%
#names of the columns
list(data)
# Out:
# [u'Unique Key',
#  u'Created Date',
#  u'Closed Date',
#  u'Agency',
#  u'Agency Name',
#  u'Complaint Type',
#  u'Descriptor',
#  u'Location Type',
#  u'Incident Zip',
#  u'Incident Address',
#  u'Street Name',
#  u'Cross Street 1',
#  u'Cross Street 2',
#  u'Intersection Street 1',
#  u'Intersection Street 2',
#  u'Address Type',
#  u'City',
#  u'Landmark',
#  u'Facility Type',
#  u'Status',
#  u'Due Date',
#  u'Resolution Description',
#  u'Resolution Action Updated Date',
#  u'Community Board',
#  u'Borough',
#  u'X Coordinate (State Plane)',
#  u'Y Coordinate (State Plane)',
#  u'Park Facility Name',
#  u'Park Borough',
#  u'School Name',
#  u'School Number',
#  u'School Region',
#  u'School Code',
#  u'School Phone Number',
#  u'School Address',
#  u'School City',
#  u'School State',
#  u'School Zip',
#  u'School Not Found',
#  u'School or Citywide Complaint',
#  u'Vehicle Type',
#  u'Taxi Company Borough',
#  u'Taxi Pick Up Location',
#  u'Bridge Highway Name',
#  u'Bridge Highway Direction',
#  u'Road Ramp',
#  u'Bridge Highway Segment',
#  u'Garage Lot Name',
#  u'Ferry Direction',
#  u'Ferry Terminal Name',
#  u'Latitude',
#  u'Longitude',
#  u'Location']

# %% [markdown]
# Next 3 cells are just my tests

# %%
h = data.head()

# %%
h['Complaint Type']
# Out:
# 0    Noise
# 1    Noise
# 2    Noise
# 3    Noise
# 4    Noise
# Name: Complaint Type, dtype: object

# %%
h[h['Complaint Type']=='Noise']
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    31888179  11/01/2015 02:15:00 PM  11/02/2015 09:00:00 AM    DEP
# 1    31889954  11/01/2015 02:34:00 PM  11/08/2015 10:45:00 AM    DEP
# 2    31891076  11/01/2015 10:05:00 PM  11/02/2015 08:40:00 AM    DEP
# 3    31891599  11/01/2015 07:42:00 AM                     NaN    DEP
# 4    31902078  11/03/2015 09:27:00 PM  11/09/2015 10:00:00 PM    DEP
#
#                               Agency Name Complaint Type  \
# 0  Department of Environmental Protection          Noise
# 1  Department of Environmental Protection          Noise
# 2  Department of Environmental Protection          Noise
# 3  Department of Environmental Protection          Noise
# 4  Department of Environmental Protection          Noise
#
#                                      Descriptor  Location Type  Incident Zip  \
# 0                           Noise: Alarms (NR3)            NaN       11366.0
# 1          Noise: Boat(Engine,Music,Etc) (NR10)            NaN       10282.0
# 2                      Noise, Barking Dog (NR5)            NaN       10023.0
# 3  Noise: Construction Before/After Hours (NM1)            NaN       11232.0
# 4          Noise: Boat(Engine,Music,Etc) (NR10)            NaN       11354.0
#
#         Incident Address                    ...                     \
# 0  159-06 UNION TURNPIKE                    ...
# 1        8 RIVER TERRACE                    ...
# 2   119 WEST   71 STREET                    ...
# 3           904 4 AVENUE                    ...
# 4                    NaN                    ...
#
#   Bridge Highway Name Bridge Highway Direction Road Ramp  \
# 0                 NaN                      NaN       NaN
# 1                 NaN                      NaN       NaN
# 2                 NaN                      NaN       NaN
# 3                 NaN                      NaN       NaN
# 4                 NaN                      NaN       NaN
#
#   Bridge Highway Segment Garage Lot Name Ferry Direction Ferry Terminal Name  \
# 0                    NaN             NaN             NaN                 NaN
# 1                    NaN             NaN             NaN                 NaN
# 2                    NaN             NaN             NaN                 NaN
# 3                    NaN             NaN             NaN                 NaN
# 4                    NaN             NaN             NaN                 NaN
#
#     Latitude  Longitude                                  Location
# 0  40.720328 -73.807761  (40.720328269590894, -73.80776061338688)
# 1  40.715904 -74.016478     (40.715903834361, -74.01647820382685)
# 2  40.777070 -73.980055    (40.7770700173837, -73.98005490162336)
# 3  40.655822 -74.002865    (40.6558219386325, -74.00286523067972)
# 4  40.772013 -73.848860  (40.772012875575754, -73.84885976567074)
#
# [5 rows x 53 columns]

# %% [markdown]
# ### Number of times wach type of complaint appears

# %%
data.Descriptor.value_counts().sort_values()
# Out:
# Noise: Vehicle (NR2)                                         1
# Noise: Loud Music/Daytime (Mark Date And Time) (NN1)         6
# Noise: Loud Music/Nighttime(Mark Date And Time) (NP1)        6
# Noise: Other Noise Sources (Use Comments) (NZZ)             22
# Noise: Boat(Engine,Music,Etc) (NR10)                       142
# Noise, Other Animals (NR6)                                 265
# Noise:  lawn care equipment (NCL)                          626
# Noise: Manufacturing Noise (NK1)                           716
# Noise, Ice Cream Truck (NR4)                              1869
# Noise: Private Carting Noise (NQ1)                        1947
# Noise: Jack Hammering (NC2)                               4466
# Noise: Alarms (NR3)                                       5484
# Noise: air condition/ventilation equipment (NV1)          6032
# Noise, Barking Dog (NR5)                                  9628
# Noise: Construction Equipment (NC1)                      10950
# Noise: Construction Before/After Hours (NM1)             40134
# Name: Descriptor, dtype: int64

# %%
#plot the values
data.Descriptor.value_counts().sort_values().plot(kind='bar',alpha=0.75, figsize = (30,10), fontsize=20)

# %% [markdown]
# ### Number of times each street appears (can be done by zip code too, but don't use Incident Address; there are way to many of them)

# %%
data['Street Name'].value_counts().sort_values()
# Out:
# PURDY STREET                1
# FEDERAL PLAZA               1
# LINWOOD ST                  1
# MARTHA STREET               1
# COLGATE AVE                 1
# BRIGHTON BCH                1
# BRIGHTON SECOND PLACE       1
# MARLBORO ROAD               1
# FORT HAMILTON PARKWA        1
# 35 AVE                      1
# 39 AVE                      1
# SEVENTH AVE                 1
# MANAHAN STREET              1
# 58 PL                       1
# THORNHILL AVENUE            1
# CENTRAL PARK W              1
# HIGHLAND ROAD               1
# 201 PLACE                   1
# DIANA TRAIL                 1
# NEW UTRECHT AVE             1
# NORTON AVENUE               1
# TUNNEL EXIT STREET          1
# RIDGEWOOD PLACE             1
# BEACH   89 STREET           1
# WINDSOR ROAD                1
# 72 AVE                      1
# 197 ST                      1
# FRESH PD ROAD               1
# SMART STREET                1
# EAST B'WAY                  1
#                          ...
# WEST   34 STREET          196
# WEST   52 STREET          198
# EAST   44 STREET          198
# WEST   53 STREET          202
# 6 AVENUE                  203
# GRAND STREET              205
# 4 AVENUE                  208
# OCEAN AVENUE              209
# MADISON AVENUE            224
# 7 AVENUE                  224
# GREENWICH STREET          238
# BEDFORD AVENUE            240
# PARK AVENUE               244
# EAST   89 STREET          259
# EAST   34 STREET          271
# MYRTLE AVENUE             275
# COLUMBUS AVENUE           276
# LEXINGTON AVENUE          298
# 8 AVENUE                  314
# EAST   14 STREET          327
# QUEENS BOULEVARD          328
# FULTON STREET             352
# WEST END AVENUE           386
# 5 AVENUE                  390
# 2 AVENUE                  436
# 1 AVENUE                  452
# MORGAN AVENUE             478
# 3 AVENUE                  543
# BROADWAY                 1079
# UNION TURNPIKE           1815
# Name: Street Name, dtype: int64

# %%
#Plot of the values. I will only plot the highest 30 values since there are too many addresses!
data['Street Name'].value_counts().sort_values().tail(30).plot(kind='bar',alpha=0.75, figsize = (30,10), fontsize=20)

# %% [markdown]
# Union Turnpike has a lot of incidents. Here it is in a map:
# https://www.google.dk/maps/place/Union+Tpke,+New+York,+EE.+UU./@40.730803,-73.7773454,17z/data=!3m1!4b1!4m5!3m4!1s0x89c261a114efcb17:0x508e4a6a60f00a52!8m2!3d40.730803!4d-73.7751567
#
# It's the name of a street in Queens, I'm not familiar with NY but I belive it's not considered "city center".
#
# 3rd Avenue has also significant cases but it's in the city center.

# %% [markdown]
# ### Number of complaints that happened each year

# %%
data['Created Date'].head()
# Out:
# 0    11/01/2015 02:15:00 PM
# 1    11/01/2015 02:34:00 PM
# 2    11/01/2015 10:05:00 PM
# 3    11/01/2015 07:42:00 AM
# 4    11/03/2015 09:27:00 PM
# Name: Created Date, dtype: object

# %%
#add a column with the year from the Date
data['year'] = pd.DatetimeIndex(data['Created Date']).year

# %%
data.head(1) #now we have 54 columns
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    31888179  11/01/2015 02:15:00 PM  11/02/2015 09:00:00 AM    DEP
#
#                               Agency Name Complaint Type           Descriptor  \
# 0  Department of Environmental Protection          Noise  Noise: Alarms (NR3)
#
#    Location Type  Incident Zip       Incident Address  ...   \
# 0            NaN       11366.0  159-06 UNION TURNPIKE  ...
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name  \
# 0                      NaN       NaN                    NaN             NaN
#
#   Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0             NaN                 NaN  40.720328 -73.807761
#
#                                    Location  year
# 0  (40.720328269590894, -73.80776061338688)  2015
#
# [1 rows x 54 columns]

# %%
data['year'].value_counts().sort_index()
# Out:
# 2015    10632
# 2016    58493
# 2017    13169
# Name: year, dtype: int64

# %%
data['year'].value_counts().sort_index().plot(kind='bar',alpha=0.75, figsize = (30,10), fontsize=20)

# %% [markdown]
# There is a huge increase from 2015 to 2016 but I think it's because the dates are in the  "american way" of writing dates (month/day/year) so the data starts from November 2015. And obviously the data from 2017 is not complete. I don't think we can get anything from here...

# %%
data['Created time'] = pd.DatetimeIndex(data['Created Date']).time

# %%
data['DayOfMonth'] = pd.DatetimeIndex(data['Created Date']).day

# %%
data['Month'] = pd.DatetimeIndex(data['Created Date']).month

# %%
data.head(3)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    31888179  11/01/2015 02:15:00 PM  11/02/2015 09:00:00 AM    DEP
# 1    31889954  11/01/2015 02:34:00 PM  11/08/2015 10:45:00 AM    DEP
# 2    31891076  11/01/2015 10:05:00 PM  11/02/2015 08:40:00 AM    DEP
#
#                               Agency Name Complaint Type  \
# 0  Department of Environmental Protection          Noise
# 1  Department of Environmental Protection          Noise
# 2  Department of Environmental Protection          Noise
#
#                              Descriptor  Location Type  Incident Zip  \
# 0                   Noise: Alarms (NR3)            NaN       11366.0
# 1  Noise: Boat(Engine,Music,Etc) (NR10)            NaN       10282.0
# 2              Noise, Barking Dog (NR5)            NaN       10023.0
#
#         Incident Address  ...  Garage Lot Name Ferry Direction  \
# 0  159-06 UNION TURNPIKE  ...              NaN             NaN
# 1        8 RIVER TERRACE  ...              NaN             NaN
# 2   119 WEST   71 STREET  ...              NaN             NaN
#
#   Ferry Terminal Name   Latitude  Longitude  \
# 0                 NaN  40.720328 -73.807761
# 1                 NaN  40.715904 -74.016478
# 2                 NaN  40.777070 -73.980055
#
#                                    Location  year  Created time  DayOfMonth  \
# 0  (40.720328269590894, -73.80776061338688)  2015      14:15:00           1
# 1     (40.715903834361, -74.01647820382685)  2015      14:34:00           1
# 2    (40.7770700173837, -73.98005490162336)  2015      22:05:00           1
#
#   Month
# 0    11
# 1    11
# 2    11
#
# [3 rows x 57 columns]

# %% [markdown]
# ### Let's see what happened in Union Turnpike

# %%
#create a df with index by street name
data_street = data.set_index(['Street Name'])

# %%
#locate UNION TURNPIKE
data_street.loc[('UNION TURNPIKE')].head(3)
# Out:
#                 Unique Key            Created Date             Closed Date  \
# Street Name
# UNION TURNPIKE    31888179  11/01/2015 02:15:00 PM  11/02/2015 09:00:00 AM
# UNION TURNPIKE    31964965  11/12/2015 02:10:00 PM  11/12/2015 03:00:00 PM
# UNION TURNPIKE    32105861  12/01/2015 10:59:00 AM  12/01/2015 06:00:00 PM
#
#                Agency                             Agency Name Complaint Type  \
# Street Name
# UNION TURNPIKE    DEP  Department of Environmental Protection          Noise
# UNION TURNPIKE    DEP  Department of Environmental Protection          Noise
# UNION TURNPIKE    DEP  Department of Environmental Protection          Noise
#
#                          Descriptor  Location Type  Incident Zip  \
# Street Name
# UNION TURNPIKE  Noise: Alarms (NR3)            NaN       11366.0
# UNION TURNPIKE  Noise: Alarms (NR3)            NaN       11366.0
# UNION TURNPIKE  Noise: Alarms (NR3)            NaN       11366.0
#
#                      Incident Address  ...   Garage Lot Name Ferry Direction  \
# Street Name                            ...
# UNION TURNPIKE  159-06 UNION TURNPIKE  ...               NaN             NaN
# UNION TURNPIKE  159-06 UNION TURNPIKE  ...               NaN             NaN
# UNION TURNPIKE  159-06 UNION TURNPIKE  ...               NaN             NaN
#
#                Ferry Terminal Name   Latitude  Longitude  \
# Street Name
# UNION TURNPIKE                 NaN  40.720328 -73.807761
# UNION TURNPIKE                 NaN  40.720328 -73.807761
# UNION TURNPIKE                 NaN  40.720328 -73.807761
#
#                                                 Location  year  Created time  \
# Street Name
# UNION TURNPIKE  (40.720328269590894, -73.80776061338688)  2015      14:15:00
# UNION TURNPIKE  (40.720328269590894, -73.80776061338688)  2015      14:10:00
# UNION TURNPIKE  (40.720328269590894, -73.80776061338688)  2015      10:59:00
#
#                DayOfMonth  Month
# Street Name
# UNION TURNPIKE          1     11
# UNION TURNPIKE         12     11
# UNION TURNPIKE          1     12
#
# [3 rows x 56 columns]

# %%
#Obtain occurrences of types of noises
data_street.loc['UNION TURNPIKE']['Descriptor'].value_counts().sort_values()
# Out:
# Noise: Construction Equipment (NC1)                    1
# Noise: Jack Hammering (NC2)                            2
# Noise: Construction Before/After Hours (NM1)           4
# Noise, Barking Dog (NR5)                               8
# Noise: air condition/ventilation equipment (NV1)      10
# Noise: Alarms (NR3)                                 1790
# Name: Descriptor, dtype: int64

# %%
data_street.loc['UNION TURNPIKE']['Descriptor'].value_counts().sort_values().plot(kind='bar',alpha=0.75,figsize = (30,10),fontsize=20)

# %% [markdown]
# Almost all of the complaints where because of alarms!

# %% [markdown]
# Other possible analysis:
#     - When did most of these complaints happen? (year, date, TIME)
#     - Why?
#     - Obtain data from the NYPD and see if there is any theft, or violence cases in those dates that can correlate
#     - Maybe there is data from the Department of Environmental Protection (where the complaints were registered) that gives  more context

# %% [markdown]
# ## What time did people complain at? ##

# %%
len(data['Created time'])

# %%
data['Created time'].value_counts().head()
# Out:
# 09:37:00    132
# 08:36:00    125
# 09:27:00    119
# 09:33:00    117
# 22:33:00    117
# Name: Created time, dtype: int64

# %% [markdown]
# Most of the complaints happened at the mornings. Was the people more irascible just before going to work?

# %%
compl_time=data['Created time'].value_counts().sort_index().plot(kind='bar',alpha=0.75,figsize = (30,10),fontsize=20,rot=45)

for label in compl_time.xaxis.get_ticklabels():
    label.set_visible(False)

for label in compl_time.xaxis.get_ticklabels()[::200]:
    label.set_visible(True)

# %%
data['Created time'].hist(bins=20,figsize = (30,10),xlabelsize=20,ylabelsize=20,facecolor='lightblue')

# %%
len(data)
# Out:
# 82294

# %% [markdown]
# ## Number of complaints depending on the month##

# %%
data['Month'].hist(bins=12,figsize = (30,10),xlabelsize=20,ylabelsize=20,facecolor='lightblue')
